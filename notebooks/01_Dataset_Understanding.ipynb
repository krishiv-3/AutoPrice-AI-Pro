# %% [markdown]
# # Sprint 1 – Dataset Understanding
#
# ## Objective
#
# The objective of this sprint is to understand the dataset before performing any preprocessing or machine learning.
#
# A Machine Learning model is only as good as the data it learns from.
#
# Therefore, before writing any model, we must inspect the dataset, understand every feature, identify potential problems, and verify data quality.

# %% [markdown]
# # Why Dataset Understanding?
#
# Imagine a doctor prescribing medicine without checking the patient.
#
# That would be dangerous.
#
# Similarly, training a Machine Learning model without understanding the dataset often leads to poor models and incorrect conclusions.
#
# Professional Data Scientists always inspect the dataset before building models.

# %%
# ==========================================
# Sprint 1 - Dataset Understanding
# ==========================================

import numpy as np 
import pandas as pd 

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
df = pd.read_csv("../data/ford.csv")
df.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7         1.0
# 1    Focus  2018  14000       Manual     9083   Petrol  150  57.7         1.0
# 2    Focus  2017  13000       Manual    12456   Petrol  150  57.7         1.0
# 3   Fiesta  2019  17500       Manual    10460   Petrol  145  40.3         1.5
# 4   Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7         1.0

# %%
df.shape
# Out:
# (17966, 9)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 17966 entries, 0 to 17965
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         17966 non-null  str
#  1   year          17966 non-null  int64
#  2   price         17966 non-null  int64
#  3   transmission  17966 non-null  str
#  4   mileage       17966 non-null  int64
#  5   fuelType      17966 non-null  str
#  6   tax           17966 non-null  int64
#  7   mpg           17966 non-null  float64
#  8   engineSize    17966 non-null  float64
# dtypes: float64(2), int64(4), str(3)
# memory usage: 1.2 MB
