# %% [markdown]
# # Sprint 9 - Hyperparameter Tuning
#
# ## Objective
#
# In this notebook, we will optimize the Random Forest Regressor using hyperparameter tuning and cross-validation.
#
# The baseline Random Forest achieved an R² of 0.93 and an RMSE of 1255.71 on the test set.
#
# We will use RandomizedSearchCV to search for better hyperparameter combinations while keeping the test set untouched.
#
# The main hyperparameters we will investigate are:
#
# - n_estimators
# - max_depth
# - min_samples_split
# - min_samples_leaf
# - max_features
